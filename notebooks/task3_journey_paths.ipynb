# %% [markdown]
# # Task 3 — Journey paths & transitions
#
# Common multi-sensor paths and facility-to-facility transitions.
#
# Plots: `outputs/plots/task3/`

# %%
from notebook_helpers import run_task3, plot_task3, show_task_plots

t3 = run_task3(force_recompute=False)
t3.get("journey_devices", "—")
# Out:
# 131320

# %%
plot_task3()
show_task_plots(3)

from notebook_helpers import plot_mall_maps
from IPython.display import Image, display

map_plot_dir = plot_mall_maps()
display(Image(filename=str(map_plot_dir / "task3_transitions_mall_map.png")))
display(Image(filename=str(map_plot_dir / "task3_top_paths_mall_map.png")))
# Out:
# 6 plots in /Users/zohaibsarwar/Documents/GitHub/Mall_Footfall_Data_Analysis_Allunite/outputs/plots/task3
# journey_breadth_histogram.png
# top_journey_paths.png
# top_paths_mall_map.png
# top_transitions.png
# transition_heatmap.png
# transitions_mall_map.png
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 show_task_plots(3)
#       4 from IPython.display import Image, display
# ----> 5 display(Image(filename="../outputs/plots/task3_transitions_mall_map.png"))
#       6 display(Image(filename="../outputs/plots/task3_top_paths_mall_map.png"))
#
# File ~/anaconda3/envs/pinn-tf/lib/python3.10/site-packages/IPython/core/display.py:1053, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#    1051 self.unconfined = unconfined
#    1052 self.alt = alt
# ...

# %%
t3["top_paths"].head(15)
