# %% [markdown]
# # Task 3 — Journey paths & transitions
#
# Common multi-sensor paths and facility-to-facility transitions.
#
# Plots: `outputs/plots/task3/`

# %%
from notebook_helpers import run_task3, plot_task3, show_task_plots

t3 = run_task3(force_recompute=False)
t3.get("journey_devices", "—")

# %%
plot_task3()
show_task_plots(3)

from IPython.display import Image, display
display(Image(filename="../outputs/plots/task3_transitions_mall_map.png"))
display(Image(filename="../outputs/plots/task3_top_paths_mall_map.png"))

# %%
t3["top_paths"].head(15)
