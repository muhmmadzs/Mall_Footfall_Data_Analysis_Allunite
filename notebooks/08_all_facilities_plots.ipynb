# %% [markdown]
# # Facility plots (optional)
#
# Use **09_footfall_dashboard.ipynb** for the main Plan A vs Plan B comparison.
#
# This notebook is kept for EDA-style facility charts from `run_analysis.py` footfall plots only.

# %%
from notebook_helpers import show_figure, PLAN_A_OUTPUT, PLAN_B_OUTPUT
show_figure(PLAN_B_OUTPUT, "comparison_daily_footfall.png")
show_figure(PLAN_A_OUTPUT, "footfall_weekly_totals.png")
