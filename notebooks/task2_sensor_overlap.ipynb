# %% [markdown]
# # Task 2 — Multi-sensor device overlap
#
# How many unique devices are seen at more than one sensor? Which sensor pairs share the most devices?
#
# Plots: `outputs/plots/task2/`

# %%
from notebook_helpers import run_task2, plot_task2, show_task_plots

t2 = run_task2(force_recompute=False)
t2["summary"]
# Out:
# {'total_unique_devices_clean': 2042923,
#  'multi_sensor_devices': 131320,
#  'multi_sensor_rate': 0.06428044522480779}

# %%
plot_task2()
show_task_plots(2)

# Mall floor-plan overlay (assets/1.png, assets/2.png)
from notebook_helpers import plot_mall_maps
from IPython.display import Image, display

map_plot_dir = plot_mall_maps()
display(Image(filename=str(map_plot_dir / "task2_overlap_mall_map.png")))
# Out:
# 5 plots in /Users/zohaibsarwar/Documents/GitHub/Mall_Footfall_Data_Analysis_Allunite/outputs/plots/task2
# devices_per_facility.png
# jaccard_overlap_heatmap.png
# multi_sensor_summary.png
# overlap_mall_map.png
# top_sensor_pairs.png

# %%
t2["pair_counts"].head(10)
# Out:
#     facility_num_x  facility_num_y  shared_devices  devices_facility_x  \
# 0            66330           66331           58355              414628
# 25           66333           66342           43278              121450
# 35           66340           66342            8926              389401
# 20           66332           66342            7334              211156
# 26           66335           66336            7318              258815
# 1            66330           66332            5468              414628
# 31           66336           66340            5156              253537
# 8            66331           66332            4925              212352
# 7            66330           66342            4290              414628
# 24           66333           66340            4120              121450
#
#     devices_facility_y  union_devices  jaccard_overlap  \
# 0               212352         568625         0.102625
# 25              332881         411053         0.105286
# ...
